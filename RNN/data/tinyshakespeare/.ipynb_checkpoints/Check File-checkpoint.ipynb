# %%
import pickle

# %%
with open('vocab.pkl', 'rb') as f:
    data_list = []
    while True:
        try:
            data = pickle.load(f)
        except EOFError:
            break
        data_list.append(data)

# %%
data_list
# Out:
# [(' ',
#   'e',
#   't',
#   'o',
#   'a',
#   'h',
#   's',
#   'r',
#   'n',
#   'i',
#   '\r',
#   '\n',
#   'l',
#   'd',
#   'u',
#   'm',
#   'y',
#   ',',
#   'w',
#   'f',
#   'c',
#   'g',
#   'I',
#   'b',
#   'p',
#   ':',
#   '.',
#   'A',
#   'v',
#   'k',
#   'T',
#   "'",
#   'E',
#   'O',
#   'N',
#   'R',
#   'S',
#   'L',
#   'C',
#   ';',
#   'W',
#   'U',
#   'H',
#   'M',
#   'B',
#   '?',
#   'G',
#   '!',
#   'D',
#   '-',
#   'F',
#   'Y',
#   'P',
#   'K',
#   'V',
#   'j',
#   'q',
#   'x',
#   'z',
#   'J',
#   'Q',
#   'Z',
#   'X',
#   '3',
#   '&',
#   '$')]

# %%
vocab.size()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-563165a48d99> in <module>
# ----> 1 vocab.size()
#
# NameError: name 'vocab' is not defined

# %%
import numpy as np
data = np.load('data.npy')

# %%
data
# Out:
# array([50,  9,  7, ..., 26, 10, 11])

# %%
data.shape
# Out:
# (1155394,)

# %%
for d in data:
    if d == 50:
        print(d)
# Out:
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# ...
